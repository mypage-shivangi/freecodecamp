# %% [markdown]
# <a href="https://colab.research.google.com/github/mypage-shivangi/freecodecamp/blob/main/mean_variance_standard_deviation_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/freeCodeCamp/boilerplate-mean-variance-standard-deviation-calculator.git
# Out:
# Cloning into 'boilerplate-mean-variance-standard-deviation-calculator'...
# remote: Enumerating objects: 39, done.
# remote: Total 39 (delta 0), reused 0 (delta 0), pack-reused 39 (from 1)
# Receiving objects: 100% (39/39), 10.77 KiB | 3.59 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd boilerplate-mean-variance-standard-deviation-calculator
# Out:
# /content/boilerplate-mean-variance-standard-deviation-calculator

# %%
# !ls
# Out:
# main.py  mean_var_std.py  README.md  requirements.txt  test_module.py

# %%
# !python main.py
# Out:
# {'mean': [[3.0, 4.0, 5.0], [1.0, 4.0, 7.0], 4.0], 'variance': [[6.0, 6.0, 6.0], [0.6666666666666666, 0.6666666666666666, 0.6666666666666666], 6.666666666666667], 'standard deviation': [[2.449489742783178, 2.449489742783178, 2.449489742783178], [0.816496580927726, 0.816496580927726, 0.816496580927726], 2.581988897471611], 'max': [[6, 7, 8], [2, 5, 8], 8], 'min': [[0, 1, 2], [0, 3, 6], 0], 'sum': [[9, 12, 15], [3, 12, 21], 36]}
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.002s
#
# OK
